# %%
## This program creates plots for result insights for the presentation

# %%
## Visualize results
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ckd_data = pd.read_csv('./input/ckd_inputdata.csv')
print(ckd_data.shape)
## Considering a sample of 2 patients per visualization
## 70 , 251 for true
# 298, 105 for false
# Out:
# (3865, 32)

# %%
sub_data[['id', 'gender']].iloc[0]
# Out:
# id        105
# gender      1
# Name: 513, dtype: int64

# %%
## False predictions
for i in range(300):
    if i in [105, 298]:
        sub_data = ckd_data[(ckd_data.id == i)  ]
        print(sub_data[['id', 'gender']].iloc[0])
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 2, color = 'red')
        plt.title('Stage Progress examples with False prediction')
        plt.xlabel('time')
        plt.ylabel('Creatinine')
    else:
        sub_data = ckd_data[(ckd_data.id == i) ]
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 1, color = 'grey')
        
plt.show()
# Out:
# id        105
# gender      1
# Name: 513, dtype: int64
# id        298
# gender      0
# Name: 1431, dtype: int64

# %%
for i in range(300):
    if i in [70 , 251]:
        sub_data = ckd_data[(ckd_data.id == i)  ]
        print(sub_data[['id', 'gender']].iloc[0])
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 2, color = 'red')
        plt.title('Stage Progress examples with False prediction')
        plt.xlabel('time')
        plt.ylabel('Creatinine')
    else:
        sub_data = ckd_data[(ckd_data.id == i) ]
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 1, color = 'grey')
        

plt.show()
# Out:
# id        70
# gender     1
# Name: 340, dtype: int64
# id        251
# gender      1
# Name: 1205, dtype: int64

# %%
for i in range(300):
    if i in [70 , 251]:
        sub_data = ckd_data[(ckd_data.id == i)  ]
        print(sub_data[['id', 'gender']].iloc[0])
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 2, color = 'red')
        plt.title('Stage Progress examples with True prediction')
        plt.xlabel('time')
        plt.ylabel('Creatinine')
    else:
        sub_data = ckd_data[(ckd_data.id == i)]
        plt.plot(sub_data.time, sub_data.vCreatinine, alpha=0.5, linewidth= 1, color = 'grey')
        

plt.show()
# Out:
# id        70
# gender     1
# Name: 340, dtype: int64
# id        251
# gender      1
# Name: 1205, dtype: int64
