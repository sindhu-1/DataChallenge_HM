# %%
#########################################################
# Program name: cdkModel.py
# Description: This program builds a CNN-LSTM model for 
# predicting the CKD outcome for a given patient based on
# longitudinal data.
# Input Data : ./input
# Output Data: ./output
#########################################################
